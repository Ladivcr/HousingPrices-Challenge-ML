# %% [markdown]
# # Datos

# %%
"""
Archivo Creado: 13 Septiembre - 12:02 A. M.
Escrito Por: José Vidal Cardona Rosas 
"""
# Importamos las librerias que vamos a utilizar para trabajar con los datos
import pandas as pd
import seaborn as sns

#Importamos los datos con los que vamos a trabajar
house_data_train = pd.DataFrame(pd.read_csv('/content/train.csv'))
house_data_test = pd.DataFrame(pd.read_csv('/content/test.csv'))
Y_real = pd.DataFrame(pd.read_csv('/content/sample_submission.csv'))


house_data_train.columns
